# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 51)
y = (x == 3)
plt.scatter(x, y, ) # Don't want to use line, need to make this dots

# %%
def exp_dist(x, beta=0.1):
    return 1/beta * np.e ** (-x / beta)

# %%
x = np.linspace(0, 3, 70)
y = exp_dist(x, 0.5)
plt.scatter(x, y)
